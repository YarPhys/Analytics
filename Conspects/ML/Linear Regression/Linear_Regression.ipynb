# %%
import numpy as np
import pandas as pd


df = pd.read_csv('Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop(df.columns[0], axis=1, inplace=True)
df.head(2)
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error


X_train, X_test, y_train, y_test = train_test_split(df['YearsExperience'],
                                                    df['Salary'],
                                                    test_size=0.2,
                                                    random_state=10)
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1, 1)
linreg = LinearRegression()
linreg.fit(X_train, y_train)
y_pred = linreg.predict(X_test)
linreg.coef_
# Out:
# array([9356.86299354])

# %%
r2_score(y_pred, y_test)
# Out:
# 0.9772735206341413

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 2741.2806275420794

# %% [markdown]
# Новый датасет

# %%
df = pd.read_csv('poly.csv')
df.head()
# Out:
#           X           Y
# 0 -3.292157  -53.468412
# 1  0.799528   -1.262560
# 2 -0.936214   -3.506193
# 3 -4.722680 -107.223200
# 4 -3.602674  -49.131950

# %%
from sklearn.linear_model import Ridge  # линейная модель с L_2 регуляризацией
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures


X_train, X_test, y_train, y_test = train_test_split(df['X'],
                                                    df['Y'],
                                                    test_size=0.2,
                                                    random_state=10)
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1, 1)


scores = []
for alph in range(1, 121):
    for i in range(1, 8):
        linreg = make_pipeline(
            PolynomialFeatures(degree=i),
            Ridge(alpha = alph)
        )
        linreg.fit(X_train, y_train)
        y_pred = linreg.predict(X_test)
        scores.append((alph, i, r2_score(y_pred, y_test)))

# %%
df = pd.DataFrame(scores, columns=['alpha', 'degree', 'r2_score'])
df.head()
# Out:
#    alpha  degree  r2_score
# 0      1       1  0.362998
# 1      1       2 -1.550113
# 2      1       3  0.900301
# 3      1       4  0.944999
# 4      1       5  0.815090

# %%
df[(df['r2_score'] == df['r2_score'].max())]
# Out:
#      alpha  degree  r2_score
# 143     21       4  0.951101

# %%
model = make_pipeline(
    PolynomialFeatures(degree=4),
    Ridge(alpha=21)
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
r2_score(y_pred, y_test)
# Out:
# 0.9511007756545717
